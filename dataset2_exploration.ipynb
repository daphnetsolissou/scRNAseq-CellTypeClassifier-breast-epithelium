# %% [markdown]
# ## Dataset 2 exploration

# %% [markdown]
# This is an exploration of the second dataset in the pipeline (10X platform).

# %%
import pandas as pd
import gzip
import os

import seaborn as sns

# %%
DATA_DIR = os.path.join(os.getcwd(), 'data')

# %% [markdown]
# ### Individual 4

# %%
file_path_id4 = DATA_DIR + '\GSM3099846_Ind4_Expression_Matrix.txt.gz'

# %%
with gzip.open(file_path_id4, 'rb') as f:
    data_id4 = pd.read_csv(f, sep='\t', index_col=0)

# %%
data_id4.head()
# Out:
#               Ind4_AAACATACGTACAC  Ind4_AAACATTGCCTCCA  Ind4_AAACATTGTGAAGA  \
# RP11-34P13.3                    0                    0                    0
# FAM138A                         0                    0                    0
# OR4F5                           0                    0                    0
# RP11-34P13.7                    0                    0                    0
# RP11-34P13.8                    0                    0                    0
#
#               Ind4_AAACATTGTTCTTG  Ind4_AAACCGTGCCTTAT  Ind4_AAACCGTGCTACTT  \
# RP11-34P13.3                    0                    0                    0
# FAM138A                         0                    0                    0
# OR4F5                           0                    0                    0
# RP11-34P13.7                    0                    0                    0
# RP11-34P13.8                    0                    0                    0
#
# ...

# %%
data_id4.shape
# Out:
# (33694, 4116)

# %%
data_id4.describe()
# Out:
#        Ind4_AAACATACGTACAC  Ind4_AAACATTGCCTCCA  Ind4_AAACATTGTGAAGA  \
# count         33694.000000         33694.000000         33694.000000
# mean              0.260017             0.135573             0.310144
# std               6.565391             4.116296             5.334024
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max            1060.000000           652.000000           602.000000
#
#        Ind4_AAACATTGTTCTTG  Ind4_AAACCGTGCCTTAT  Ind4_AAACCGTGCTACTT  \
# count         33694.000000         33694.000000         33694.000000
# mean              0.081469             0.366890             0.128124
# std               1.930479             8.374352             2.130809
# ...

# %% [markdown]
# ### Individual 5

# %%
file_path_id5 = DATA_DIR + '\GSM3099847_Ind5_Expression_Matrix.txt.gz'

# %%
with gzip.open(file_path_id5, 'rb') as f:
    data_id5 = pd.read_csv(f, sep='\t', index_col=0)

# %%
data_id5.head()
# Out:
#               Ind5_AAACCTGAGAAACCTA-1  Ind5_AAACCTGAGACAGAGA-1  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind5_AAACCTGAGCCAGAAC-1  Ind5_AAACCTGAGCCTATGT-1  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind5_AAACCTGAGGAGTTTA-1  Ind5_AAACCTGAGTATTGGA-1  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# ...

# %%
data_id5.shape
# Out:
# (33694, 6964)

# %%
data_id5.describe()
# Out:
#        Ind5_AAACCTGAGAAACCTA-1  Ind5_AAACCTGAGACAGAGA-1  \
# count             33694.000000             33694.000000
# mean                  0.632071                 0.253754
# std                  12.435166                 5.497499
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                1672.000000               801.000000
#
#        Ind5_AAACCTGAGCCAGAAC-1  Ind5_AAACCTGAGCCTATGT-1  \
# count             33694.000000             33694.000000
# mean                  0.397430                 0.283315
# std                   6.740121                 4.730061
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...

# %% [markdown]
# ### Individual 6

# %%
file_path_id6 = DATA_DIR + '\GSM3099848_Ind6_Expression_Matrix.txt.gz'

# %%
with gzip.open(file_path_id6, 'rb') as f:
    data_id6 = pd.read_csv(f, sep='\t', index_col=0)

# %%
data_id6.head()
# Out:
#               Ind6_AAACCTGAGAGCTGCA-2  Ind6_AAACCTGAGATATACG-2  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind6_AAACCTGCACCATCCT-2  Ind6_AAACCTGCACTCGACG-2  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind6_AAACCTGCATTTGCTT-2  Ind6_AAACCTGGTCCGAAGA-2  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# ...

# %%
data_id6.shape
# Out:
# (33694, 6014)

# %%
data_id6.describe()
# Out:
#        Ind6_AAACCTGAGAGCTGCA-2  Ind6_AAACCTGAGATATACG-2  \
# count             33694.000000             33694.000000
# mean                  0.328426                 0.356057
# std                   5.491679                 6.191388
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                 646.000000               559.000000
#
#        Ind6_AAACCTGCACCATCCT-2  Ind6_AAACCTGCACTCGACG-2  \
# count             33694.000000             33694.000000
# mean                  0.408886                 0.502493
# std                   7.006380                 7.686901
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...

# %% [markdown]
# ### Individual 7

# %%
file_path_id7 = DATA_DIR + '\GSM3099849_Ind7_Expression_Matrix.txt.gz'

# %%
with gzip.open(file_path_id7, 'rb') as f:
    data_id7 = pd.read_csv(f, sep='\t', index_col=0)

# %%
data_id7.head()
# Out:
#               Ind7_AAACCTGAGCCAGTAG-3  Ind7_AAACCTGAGCCTATGT-3  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind7_AAACCTGAGTACCGGA-3  Ind7_AAACCTGCAAGTAGTA-3  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind7_AAACCTGCACCTCGTT-3  Ind7_AAACCTGCAGCGTAAG-3  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# ...

# %%
data_id7.shape
# Out:
# (33694, 7552)

# %%
data_id7.describe()
# Out:
#        Ind7_AAACCTGAGCCAGTAG-3  Ind7_AAACCTGAGCCTATGT-3  \
# count             33694.000000             33694.000000
# mean                  1.401822                 0.280436
# std                  13.690624                 4.050673
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                 994.000000               614.000000
#
#        Ind7_AAACCTGAGTACCGGA-3  Ind7_AAACCTGCAAGTAGTA-3  \
# count             33694.000000             33694.000000
# mean                  0.452573                 0.337508
# std                   4.649983                 3.740205
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...
