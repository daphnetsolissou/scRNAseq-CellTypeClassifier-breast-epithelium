# %% [markdown]
# # Data exploration

# %%
#pip install scanpy

# %%
#pip install leidenalg
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import gzip
import os
import scanpy as sc

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset 2 exploration

# %% [markdown]
# This is an exploration of the second dataset in the pipeline (10X platform).

# %%
DATA_DIR = os.path.join(os.getcwd(), 'data')

# %% [markdown]
# ### Individual 4

# %%
file_path_id4 = DATA_DIR + '\GSM3099846_Ind4_Expression_Matrix.txt.gz'

# %%
with gzip.open(file_path_id4, 'rb') as f:
    data_id4 = pd.read_csv(f, sep='\t', index_col=0)

# %%
data_id4.head()
# Out:
#               Ind4_AAACATACGTACAC  Ind4_AAACATTGCCTCCA  Ind4_AAACATTGTGAAGA  \
# RP11-34P13.3                    0                    0                    0
# FAM138A                         0                    0                    0
# OR4F5                           0                    0                    0
# RP11-34P13.7                    0                    0                    0
# RP11-34P13.8                    0                    0                    0
#
#               Ind4_AAACATTGTTCTTG  Ind4_AAACCGTGCCTTAT  Ind4_AAACCGTGCTACTT  \
# RP11-34P13.3                    0                    0                    0
# FAM138A                         0                    0                    0
# OR4F5                           0                    0                    0
# RP11-34P13.7                    0                    0                    0
# RP11-34P13.8                    0                    0                    0
#
# ...

# %%
data_id4.shape
# Out:
# (33694, 4116)

# %%
data_id4.describe()
# Out:
#        Ind4_AAACATACGTACAC  Ind4_AAACATTGCCTCCA  Ind4_AAACATTGTGAAGA  \
# count         33694.000000         33694.000000         33694.000000
# mean              0.260017             0.135573             0.310144
# std               6.565391             4.116296             5.334024
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max            1060.000000           652.000000           602.000000
#
#        Ind4_AAACATTGTTCTTG  Ind4_AAACCGTGCCTTAT  Ind4_AAACCGTGCTACTT  \
# count         33694.000000         33694.000000         33694.000000
# mean              0.081469             0.366890             0.128124
# std               1.930479             8.374352             2.130809
# ...

# %% [markdown]
# ### Individual 5

# %%
file_path_id5 = DATA_DIR + '\GSM3099847_Ind5_Expression_Matrix.txt.gz'

# %%
with gzip.open(file_path_id5, 'rb') as f:
    data_id5 = pd.read_csv(f, sep='\t', index_col=0)

# %%
data_id5.head()
# Out:
#               Ind5_AAACCTGAGAAACCTA-1  Ind5_AAACCTGAGACAGAGA-1  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind5_AAACCTGAGCCAGAAC-1  Ind5_AAACCTGAGCCTATGT-1  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind5_AAACCTGAGGAGTTTA-1  Ind5_AAACCTGAGTATTGGA-1  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# ...

# %%
data_id5.shape
# Out:
# (33694, 6964)

# %%
data_id5.describe()
# Out:
#        Ind5_AAACCTGAGAAACCTA-1  Ind5_AAACCTGAGACAGAGA-1  \
# count             33694.000000             33694.000000
# mean                  0.632071                 0.253754
# std                  12.435166                 5.497499
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                1672.000000               801.000000
#
#        Ind5_AAACCTGAGCCAGAAC-1  Ind5_AAACCTGAGCCTATGT-1  \
# count             33694.000000             33694.000000
# mean                  0.397430                 0.283315
# std                   6.740121                 4.730061
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...

# %% [markdown]
# ### Individual 6

# %%
file_path_id6 = DATA_DIR + '\GSM3099848_Ind6_Expression_Matrix.txt.gz'

# %%
with gzip.open(file_path_id6, 'rb') as f:
    data_id6 = pd.read_csv(f, sep='\t', index_col=0)

# %%
data_id6.head()
# Out:
#               Ind6_AAACCTGAGAGCTGCA-2  Ind6_AAACCTGAGATATACG-2  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind6_AAACCTGCACCATCCT-2  Ind6_AAACCTGCACTCGACG-2  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind6_AAACCTGCATTTGCTT-2  Ind6_AAACCTGGTCCGAAGA-2  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# ...

# %%
data_id6.shape
# Out:
# (33694, 6014)

# %%
data_id6.describe()
# Out:
#        Ind6_AAACCTGAGAGCTGCA-2  Ind6_AAACCTGAGATATACG-2  \
# count             33694.000000             33694.000000
# mean                  0.328426                 0.356057
# std                   5.491679                 6.191388
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                 646.000000               559.000000
#
#        Ind6_AAACCTGCACCATCCT-2  Ind6_AAACCTGCACTCGACG-2  \
# count             33694.000000             33694.000000
# mean                  0.408886                 0.502493
# std                   7.006380                 7.686901
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...

# %% [markdown]
# ### Individual 7

# %%
file_path_id7 = DATA_DIR + '\GSM3099849_Ind7_Expression_Matrix.txt.gz'

# %%
with gzip.open(file_path_id7, 'rb') as f:
    data_id7 = pd.read_csv(f, sep='\t', index_col=0)

# %%
data_id7.head()
# Out:
#               Ind7_AAACCTGAGCCAGTAG-3  Ind7_AAACCTGAGCCTATGT-3  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind7_AAACCTGAGTACCGGA-3  Ind7_AAACCTGCAAGTAGTA-3  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# OR4F5                               0                        0
# RP11-34P13.7                        0                        0
# RP11-34P13.8                        0                        0
#
#               Ind7_AAACCTGCACCTCGTT-3  Ind7_AAACCTGCAGCGTAAG-3  \
# RP11-34P13.3                        0                        0
# FAM138A                             0                        0
# ...

# %%
data_id7.shape
# Out:
# (33694, 7552)

# %%
data_id7.describe()
# Out:
#        Ind7_AAACCTGAGCCAGTAG-3  Ind7_AAACCTGAGCCTATGT-3  \
# count             33694.000000             33694.000000
# mean                  1.401822                 0.280436
# std                  13.690624                 4.050673
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                 994.000000               614.000000
#
#        Ind7_AAACCTGAGTACCGGA-3  Ind7_AAACCTGCAAGTAGTA-3  \
# count             33694.000000             33694.000000
# mean                  0.452573                 0.337508
# std                   4.649983                 3.740205
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# The package 'scanpy' was utilized to bring the data frames into an appropriate form to continue the scRNA seq pipeline. This package is the equivalent of the 'Seurat' package of R, that was used in the paper's analysis.
#
# Following the paper's instructions genes with expression in less than three cells, as well as cells with less than 900 genes, were removed. In the filtered data, FPKM values were transformed into log-space.
#
# After that, PCA was performed using highly variable genes in the trimmed dataset. The first two PC’s were used as input to perform density clustering in order to identify groupings in the data. T-distributed statistical neighbor embedding (tSNE) was utilized to visualize. Using further scanpy functionality, marker genes for each respective cluster were identified and used for subsequent analysis.

# %%
data_id4_copy = data_id4.copy()
data_id4_copy = data_id4_copy.T

# %%
# create annotated data object (with metadata about cell type and gene ids)
adata_id4 = sc.AnnData(data_id4_copy)
adata_id4
# Out:
# AnnData object with n_obs × n_vars = 4116 × 33694

# %%
# transform data to log space
sc.pp.log1p(adata_id4)
adata_id4
# Out:
# AnnData object with n_obs × n_vars = 4116 × 33694
#     uns: 'log1p'

# %%
# filter genes based on the minimum expression threshold
sc.pp.filter_genes(adata_id4, min_cells=3)
sc.pp.filter_cells(adata_id4, min_genes=500)
sc.pp.filter_cells(adata_id4, max_genes=6000)

# %%
# filter out high mitochondrial cell expression
mito_genes = adata_id4.var_names.str.startswith('MT-')
adata_id4.obs['percent_mito'] = np.sum(adata_id4[:, mito_genes].X, axis=1) / np.sum(adata_id4.X, axis=1)
adata_id4 = adata_id4[adata_id4.obs['percent_mito'] <= 0.1]

# %%
# perform data normalization and scaling
sc.pp.normalize_total(adata_id4)
#sc.pp.log1p(adata_id4)
sc.pp.scale(adata_id4)
adata_id4
# Out:
# c:\Users\greg\anaconda3\lib\site-packages\scanpy\preprocessing\_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# AnnData object with n_obs × n_vars = 4115 × 17363
#     obs: 'n_genes', 'percent_mito'
#     var: 'n_cells', 'mean', 'std'
#     uns: 'log1p'

# %%
adata_id4.obs
# Out:
#                      n_genes  percent_mito
# Ind4_AAACATACGTACAC     2314      0.011840
# Ind4_AAACATTGCCTCCA     1402      0.016508
# Ind4_AAACATTGTGAAGA     2322      0.013869
# Ind4_AAACATTGTTCTTG      920      0.040478
# Ind4_AAACCGTGCCTTAT     3041      0.008981
# ...                      ...           ...
# Ind4_TTTCTACTTACTCT     1234      0.023980
# Ind4_TTTGACTGAGCAAA     1726      0.012009
# Ind4_TTTGACTGCTAAGC     1128      0.020722
# Ind4_TTTGCATGCCGATA     1695      0.015640
# Ind4_TTTGCATGCTCCAC     1668      0.014933
#
# [4115 rows x 2 columns]

# %%
adata_id4.var
# Out:
#                n_cells      mean       std
# RP11-34P13.7         6  0.000750  0.020247
# FO538757.2         274  0.043526  0.175948
# AP006222.2         545  0.089700  0.246562
# RP4-669L17.10       16  0.002727  0.044493
# RP11-206L10.9      135  0.022178  0.126992
# ...                ...       ...       ...
# AC007325.4         207  0.033307  0.155252
# AC007325.2           3  0.000433  0.016155
# AL354822.1          36  0.006350  0.072031
# AC004556.1           3  0.000606  0.023312
# AC240274.1          21  0.004204  0.062912
#
# [17363 rows x 3 columns]

# %%
# perform regression to remove unwanted sources of variation
sc.pp.regress_out(adata_id4, keys=['n_genes', 'percent_mito'])

# %%
# identify high variable genes for the PCA
sc.pp.highly_variable_genes(adata_id4, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(adata_id4, show=False)
# Out:
# <AxesSubplot:xlabel='mean expressions of genes', ylabel='dispersions of genes (not normalized)'>

# %%
# perform PCA using the identified highly variable genes
sc.tl.pca(adata_id4, svd_solver='arpack', use_highly_variable=True)

# %%
# compute t-SNE using the first ten principal components
sc.tl.tsne(adata_id4, n_pcs=10)
# Out:
# c:\Users\greg\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
cell_ids = adata_id4.obs.index
cell_ids
# Out:
# Index(['Ind4_AAACATACGTACAC', 'Ind4_AAACATTGCCTCCA', 'Ind4_AAACATTGTGAAGA',
#        'Ind4_AAACATTGTTCTTG', 'Ind4_AAACCGTGCCTTAT', 'Ind4_AAACCGTGCTACTT',
#        'Ind4_AAACCGTGTGTGGT', 'Ind4_AAACGCACCCTACC', 'Ind4_AAACGCACGTGTCA',
#        'Ind4_AAACGCACTTGCGA',
#        ...
#        'Ind4_TTTCCAGAACACGT', 'Ind4_TTTCGAACAGAGTA', 'Ind4_TTTCGAACCTGAAC',
#        'Ind4_TTTCGAACGTGTAC', 'Ind4_TTTCTACTGAGGGT', 'Ind4_TTTCTACTTACTCT',
#        'Ind4_TTTGACTGAGCAAA', 'Ind4_TTTGACTGCTAAGC', 'Ind4_TTTGCATGCCGATA',
#        'Ind4_TTTGCATGCTCCAC'],
#       dtype='object', length=4115)

# %%
sc.pl.tsne(adata_id4)

# %%
# clustering with leiden algorithm
sc.pp.neighbors(adata_id4, n_pcs=10)
sc.tl.leiden(adata_id4)

# %%
# identify marker genes for each cluster
sc.tl.rank_genes_groups(
    adata_id4,
    groupby='leiden',
    method='t-test',
    use_raw=False,
    log_transform=False,
    min_in_group_fraction=0.01
)
# Out:
# c:\Users\greg\anaconda3\lib\site-packages\scanpy\tools\_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# c:\Users\greg\anaconda3\lib\site-packages\scanpy\tools\_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# c:\Users\greg\anaconda3\lib\site-packages\scanpy\tools\_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# c:\Users\greg\anaconda3\lib\site-packages\scanpy\tools\_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# c:\Users\greg\anaconda3\lib\site-packages\scanpy\tools\_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# ...

# %%
basal_marker_genes = ['KRT5', 'KRT14']
luminal_marker_genes = ['KRT8', 'KRT18', 'ANKRD30A']
all_marker_genes = basal_marker_genes + luminal_marker_genes

sc.pl.dotplot(adata_id4, all_marker_genes, groupby='leiden')

# %% [markdown]
# -----

# %% [markdown]
# ## Different implementation

# %%
# filter genes based on the minimum expression threshold
sc.pp.filter_genes(adata_id4, min_cells=3)
sc.pp.filter_cells(adata_id4, min_genes=900)

# %%
# normalize and transform FPKM data into log-space
sc.pp.normalize_total(adata_id4)
sc.pp.log1p(adata_id4)

# %%
# select high-variable genes
sc.pp.highly_variable_genes(adata_id4, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
# Plot highly variable genes
sc.pl.highly_variable_genes(adata_id4, show=False)
# Out:
# <AxesSubplot:xlabel='mean expressions of genes', ylabel='dispersions of genes (not normalized)'>

# %%
# perform PCA
sc.tl.pca(adata_id4, n_comps=2, svd_solver='arpack', use_highly_variable=True)

# %% [markdown]
# ## Clustering with Leiden algorithm (scanpy's stuff)

# %%
sc.pp.neighbors(adata_id4, n_neighbors=15, use_rep='X_pca')
sc.tl.leiden(adata_id4, resolution=0.5, key_added='leiden')

# %%
sc.tl.tsne(adata_id4, n_pcs=2)

fig, ax = plt.subplots(figsize=(12, 8))
sc.pl.tsne(adata_id4, color='leiden', ax=ax, title='tSNE plot with Leiden algorithm clustering')
plt.show()
# Out:
# c:\Users\greg\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %% [markdown]
# ## Clustering with DBSCAN (wrong??)

# %%
clusterer = DBSCAN(eps=100, min_samples=50)
adata_id4.obs['dbscan_labels'] = clusterer.fit_predict(adata_id4.obsm['X_pca'])

# Optional: filter out noise points (labels == -1)
#adata_id4 = adata_id4[adata_id4.obs['dbscan_labels'] != -1]

# %%
sc.tl.tsne(adata_id4, n_pcs=2)

fig, ax = plt.subplots(figsize=(12, 8))
sc.pl.tsne(adata_id4, color='dbscan_labels', ax=ax, title='tSNE plot with DBSCAN clustering')
plt.show()
# Out:
# c:\Users\greg\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
